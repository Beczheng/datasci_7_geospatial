# %% [markdown]
# <a href="https://colab.research.google.com/github/Beczheng/datasci_7_geospatial/blob/main/HHA_507_HW_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Importing packages

# %%
import geopandas as gpd
import re
import folium
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# # 2. Loading the datasets

# %%
# Loading dataset #1

df = gpd.read_file('Birth_Statistics.geojson')
df
# Out:
#     FID    ZIP       LBW   Preterm  TeenBirth  Birth_Rate  F1stTriCare  \
# 0     1  60002  0.084837  0.134124       18.5   10.440239    74.639700
# 1     2  60010  0.052208  0.080828        1.4    3.219561    86.189946
# 2     3  60015  0.095519  0.101959        1.8    7.635261    83.544132
# 3     4  60020  0.077067  0.087777       29.9   13.737068    79.075398
# 4     5  60030  0.071311  0.086675        6.2   10.598146    81.745316
# 5     6  60031  0.081407  0.098994       10.1   10.265032    78.372131
# 6     7  60035  0.067941  0.088888        3.6    8.161008    84.821850
# 7     8  60040  0.081060  0.116597       21.7   14.259259    81.801379
# 8     9  60042  0.057217  0.103992        5.2    5.142590    74.762789
# 9    10  60044  0.045741  0.077593        4.8    8.494268    84.421498
# 10   11  60045  0.048820  0.076689        0.3    4.886430    84.572198
# 11   12  60046  0.068126  0.085630        9.1   10.183884    80.923184
# ...

# %%
# Loading dataset #2

df2 = gpd.read_file('Cancer_Rates.geojson')
df2
# Out:
#     FID    ZIP  Colorectal  Lung_Bronc  Breast_Can  Prostate_C  Urinary_Sy  \
# 0     1  60002  218.062127  419.666735  399.094836  259.205925  259.205925
# 1     2  60010  258.915706  335.464697  504.322767  499.819885  227.395533
# 2     3  60015  153.435867  230.153801  478.573777  442.041428  222.847331
# 3     4  60020  292.797189  507.515128  214.717939  302.557095  370.876440
# 4     5  60030  221.535432  284.440555  404.780789  322.730629  210.595411
# 5     6  60031  163.502110  221.518987  414.029536  303.270042  160.864979
# 6     7  60035  241.311124  475.919161  553.004659  482.622248  392.130576
# 7     8  60040   55.555556  240.740741  277.777778  185.185185  185.185185
# 8     9  60042  140.252454  315.568022  397.381954  187.003273  187.003273
# 9    10  60044  206.547558  237.529691  557.678405  413.095115  165.238046
# 10   11  60045  258.334958  316.825892  609.280562  497.172938  282.706181
# ...

# %%
# Loading dataset #3

df3 = gpd.read_file('Hospitalization_Discharge_Rates.geojson')
df3
# Out:
#     OBJECTID    ZIP  Anxiety_Di  Mood_Disor  Alcohol_re    Diabetes  \
# 0          1  60002  393.608997  359.322499  270.177604   69.637883
# 1          2  60010  132.835014  153.848463  177.863833   43.503045
# 2          3  60015  142.476163  231.371546  147.347143   18.720048
# 3          4  60020  201.704730  452.208992  406.662763   90.111739
# 4          5  60030  261.648844  237.033796  250.708822   56.958420
# 5          6  60031  240.857947  234.704641  178.445851   60.977830
# 6          7  60035  129.593011  256.951660  245.779848   25.992225
# 7          8  60040  123.456790  308.641975  320.987654   18.072289
# 8          9  60042  261.025401  374.006545  214.274583   89.011167
# 9         10  60044  182.450343  230.644773  289.166581   35.961815
# 10        11  60045  173.848054  188.470787  264.833951   20.846697
# 11        12  60046  321.294357  357.631219  252.445566   77.380468
# 12        13  60047  187.110680  161.846790  179.215714   42.367358
# ...

# %%
# Loading dataset #4

df4 = gpd.read_file('Mortality_Rates.geojson')
df4
# Out:
#     FID    ZIP  PCT_EARLY    Avg_Age    Cancer_D     Heart_D     COPD_D  \
# 0     1  60002   0.520875  71.055412  183.546648  150.623482  32.923166
# 1     2  60010   0.259170  78.499343   96.156027   87.538270  19.956911
# 2     3  60015   0.310690  78.025232  150.000000  135.820896  16.417910
# 3     4  60020   0.458126  72.811321  217.811705  209.669211  56.997455
# 4     5  60030   0.402194  73.710013  120.368316  100.399379  24.406479
# 5     6  60031   0.431511  72.295981  120.167602   95.923261  20.554985
# 6     7  60035   0.242994  78.552000  288.277391  159.258139  20.831233
# 7     8  60040   0.310523  80.101695  132.572270  180.445590  22.095378
# 8     9  60042   0.538143  68.912000   72.540073   60.840061  16.380016
# 9    10  60044   0.308196  74.576000  167.483660  126.633987  22.467320
# 10   11  60045   0.231847  78.497000   88.888889   61.170848   7.646356
# 11   12  60046   0.448470  73.662000  101.392726   99.683860   0.569622
# ...

# %%
# Loading dataset #5

df5 = gpd.read_file('STI_Rates.geojson')
df5
# Out:
#     OBJECTID    ZIP  Chlamydia_  Gonorrhea_  SHAPE_Length  SHAPE_Area  \
# 0          1  60010    5.386098    0.000000      0.585157    0.008129
# 1          2  60015   10.777043    1.369963      0.371889    0.003720
# 2          3  60020   17.323834    2.195979      0.299823    0.001693
# 3          4  60030   19.911868    1.984344      0.796327    0.008580
# 4          5  60031   23.997890    3.955696      0.533165    0.005353
# 5          6  60035   13.238596    1.173040      0.372889    0.003501
# 6          7  60040   22.222222    0.000000      0.080798    0.000180
# 7          8  60042    9.350164    0.000000      0.135803    0.000458
# 8          9  60044   12.392853    0.000000      0.293811    0.002158
# 9         10  60045   10.479626    1.096705      0.520156    0.006297
# 10        11  60046   17.785938    1.864655      0.665847    0.007422
# 11        12  60047   12.671419    0.769759      0.575797    0.009311
# ...

# %% [markdown]
# # 3. Checking missing values in the datasets

# %% [markdown]
# ## Dataset #1

# %%
# Checking missing values for dataset #1

df1.isna().sum()
# Out:
# FID             0
# ZIP             0
# LBW             0
# Preterm         0
# TeenBirth       0
# Birth_Rate      0
# F1stTriCare     0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %% [markdown]
# ## Dataset #2

# %%
# Checking missing values for dataset #2

df2.isna().sum()
# Out:
# FID             0
# ZIP             0
# Colorectal      0
# Lung_Bronc      0
# Breast_Can      0
# Prostate_C      0
# Urinary_Sy      0
# All_Cancer      0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %% [markdown]
# ## Dataset #3

# %%
# Checking missing values for dataset #3

df3.isna().sum()
# Out:
# OBJECTID        0
# ZIP             0
# Anxiety_Di      0
# Mood_Disor      0
# Alcohol_re      0
# Diabetes        0
# Hypertensi      0
# Asthma          0
# F65_FallsER     0
# Discharges      0
# MH_ER           0
# Total_MH        0
# Total_ACSC      0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %% [markdown]
# ## Dataset #4

# %%
# Checking missing values for dataset #4

df4.isna().sum()
# Out:
# FID             0
# ZIP             0
# PCT_EARLY       0
# Avg_Age         0
# Cancer_D        0
# Heart_D         0
# COPD_D          0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %% [markdown]
# ## Dataset #5

# %%
# Checking missing values for dataset #5

df5.isna().sum()
# Out:
# OBJECTID        0
# ZIP             0
# Chlamydia_      0
# Gonorrhea_      0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %% [markdown]
# # 4. Cleaning the datasets

# %% [markdown]
# ## Dataset #1

# %%
# Cleaning columns in dataset #1

def clean_column(df):
  def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

  df.columns = [clean_name(col) for col in df.columns]
  return df

new_df1 = clean_column(df1)
new_df1
# Out:
#     fid    zip       lbw   preterm  teenbirth  birthrate  f1sttricare  \
# 0     1  60002  0.084837  0.134124       18.5  10.440239    74.639700
# 1     2  60010  0.052208  0.080828        1.4   3.219561    86.189946
# 2     3  60015  0.095519  0.101959        1.8   7.635261    83.544132
# 3     4  60020  0.077067  0.087777       29.9  13.737068    79.075398
# 4     5  60030  0.071311  0.086675        6.2  10.598146    81.745316
# 5     6  60031  0.081407  0.098994       10.1  10.265032    78.372131
# 6     7  60035  0.067941  0.088888        3.6   8.161008    84.821850
# 7     8  60040  0.081060  0.116597       21.7  14.259259    81.801379
# 8     9  60042  0.057217  0.103992        5.2   5.142590    74.762789
# 9    10  60044  0.045741  0.077593        4.8   8.494268    84.421498
# 10   11  60045  0.048820  0.076689        0.3   4.886430    84.572198
# 11   12  60046  0.068126  0.085630        9.1  10.183884    80.923184
# ...

# %% [markdown]
# ## Dataset #2

# %%
# Cleaning columns in dataset #2

def clean_column(df):
  def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

  df.columns = [clean_name(col) for col in df.columns]
  return df

new_df2 = clean_column(df2)
new_df2
# Out:
#     fid    zip  colorectal   lungbronc   breastcan   prostatec   urinarysy  \
# 0     1  60002  218.062127  419.666735  399.094836  259.205925  259.205925
# 1     2  60010  258.915706  335.464697  504.322767  499.819885  227.395533
# 2     3  60015  153.435867  230.153801  478.573777  442.041428  222.847331
# 3     4  60020  292.797189  507.515128  214.717939  302.557095  370.876440
# 4     5  60030  221.535432  284.440555  404.780789  322.730629  210.595411
# 5     6  60031  163.502110  221.518987  414.029536  303.270042  160.864979
# 6     7  60035  241.311124  475.919161  553.004659  482.622248  392.130576
# 7     8  60040   55.555556  240.740741  277.777778  185.185185  185.185185
# 8     9  60042  140.252454  315.568022  397.381954  187.003273  187.003273
# 9    10  60044  206.547558  237.529691  557.678405  413.095115  165.238046
# 10   11  60045  258.334958  316.825892  609.280562  497.172938  282.706181
# ...

# %% [markdown]
# ## Dataset #3

# %%
# Cleaning columns in dataset #3

def clean_column(df):
  def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

  df.columns = [clean_name(col) for col in df.columns]
  return df

new_df3 = clean_column(df3)
new_df3
# Out:
#     objectid    zip   anxietydi   mooddisor   alcoholre    diabetes  \
# 0          1  60002  393.608997  359.322499  270.177604   69.637883
# 1          2  60010  132.835014  153.848463  177.863833   43.503045
# 2          3  60015  142.476163  231.371546  147.347143   18.720048
# 3          4  60020  201.704730  452.208992  406.662763   90.111739
# 4          5  60030  261.648844  237.033796  250.708822   56.958420
# 5          6  60031  240.857947  234.704641  178.445851   60.977830
# 6          7  60035  129.593011  256.951660  245.779848   25.992225
# 7          8  60040  123.456790  308.641975  320.987654   18.072289
# 8          9  60042  261.025401  374.006545  214.274583   89.011167
# 9         10  60044  182.450343  230.644773  289.166581   35.961815
# 10        11  60045  173.848054  188.470787  264.833951   20.846697
# 11        12  60046  321.294357  357.631219  252.445566   77.380468
# 12        13  60047  187.110680  161.846790  179.215714   42.367358
# ...

# %% [markdown]
# ## Dataset #4

# %%
# Cleaning columns in dataset #4

def clean_column(df):
  def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

  df.columns = [clean_name(col) for col in df.columns]
  return df

new_df4 = clean_column(df4)
new_df4
# Out:
#     fid    zip  pctearly     avgage     cancerd      heartd      copdd  \
# 0     1  60002  0.520875  71.055412  183.546648  150.623482  32.923166
# 1     2  60010  0.259170  78.499343   96.156027   87.538270  19.956911
# 2     3  60015  0.310690  78.025232  150.000000  135.820896  16.417910
# 3     4  60020  0.458126  72.811321  217.811705  209.669211  56.997455
# 4     5  60030  0.402194  73.710013  120.368316  100.399379  24.406479
# 5     6  60031  0.431511  72.295981  120.167602   95.923261  20.554985
# 6     7  60035  0.242994  78.552000  288.277391  159.258139  20.831233
# 7     8  60040  0.310523  80.101695  132.572270  180.445590  22.095378
# 8     9  60042  0.538143  68.912000   72.540073   60.840061  16.380016
# 9    10  60044  0.308196  74.576000  167.483660  126.633987  22.467320
# 10   11  60045  0.231847  78.497000   88.888889   61.170848   7.646356
# 11   12  60046  0.448470  73.662000  101.392726   99.683860   0.569622
# ...

# %% [markdown]
# ## Dataset #5

# %%
# Cleaning columns in dataset #5

def clean_column(df):
  def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

  df.columns = [clean_name(col) for col in df.columns]
  return df

new_df5 = clean_column(df5)
new_df5
# Out:
#     objectid    zip  chlamydia  gonorrhea  shapelength  shapearea  \
# 0          1  60010   5.386098   0.000000     0.585157   0.008129
# 1          2  60015  10.777043   1.369963     0.371889   0.003720
# 2          3  60020  17.323834   2.195979     0.299823   0.001693
# 3          4  60030  19.911868   1.984344     0.796327   0.008580
# 4          5  60031  23.997890   3.955696     0.533165   0.005353
# 5          6  60035  13.238596   1.173040     0.372889   0.003501
# 6          7  60040  22.222222   0.000000     0.080798   0.000180
# 7          8  60042   9.350164   0.000000     0.135803   0.000458
# 8          9  60044  12.392853   0.000000     0.293811   0.002158
# 9         10  60045  10.479626   1.096705     0.520156   0.006297
# 10        11  60046  17.785938   1.864655     0.665847   0.007422
# 11        12  60047  12.671419   0.769759     0.575797   0.009311
# 12        13  60048  12.976369   1.963530     0.619967   0.008306
# ...

# %% [markdown]
# # 5. Graphs and insights

# %% [markdown]
# ## Dataset #1

# %%
# Graph for dataset #1

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

new_df1.plot(
    column="teenbirth",
    cmap= 'Reds',
    ax=ax,
    cax=divider.append_axes("bottom", size="5%", pad=0.1),
    legend_kwds={"label": "Teen Birth Rate", "orientation": "horizontal"},
    legend=True,
);

# %% [markdown]
# **Description of Dataset:** This dataset contains information on births rates across Lake County, Illinois. The graph above specifically shows teen birth rates by zip code. Teen births are defined as women aged 15 to 19 years who give birth.
#
# **Patterns or Anomalies:** Teen birth rates are medium to high around the the upper half of Lake County.

# %% [markdown]
# ## Dataset #2

# %%
# Graph for dataset #2

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

new_df2.plot(
    column="breastcan",
    cmap= 'Oranges',
    ax=ax,
    cax=divider.append_axes("bottom", size="5%", pad=0.1),
    legend_kwds={"label": "Breast Cancer Rates", "orientation": "horizontal"},
    legend=True,
);

# %% [markdown]
# **Description of Dataset:** This dataset contains information on cancer rates across Lake County, Illinois. The graph above specifically shows breast cancer rates by zip code.
#
# **Patterns or Anomalies:** Breast cancer rates are medium to high around the lower half of Lake County. On the other hand, the rates are low to medium around the upper half of Lake County.

# %% [markdown]
# ## Dataset #3

# %%
# Graph for dataset #3

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

new_df3.plot(
    column="anxietydi",
    cmap= 'Greens',
    ax=ax,
    cax=divider.append_axes("bottom", size="5%", pad=0.1),
    legend_kwds={"label": "Anxiety Disorder Hospitalization Discharge Rates", "orientation": "horizontal"},
    legend=True,
);

# %% [markdown]
# **Description of Dataset:** This dataset contains information on hospitalization discharge rates across Lake County, Illinois. The graph above specifically shows hospitalization discharge rates for those with anxiety disorder by zip code. Anxiety disorders are characterized by excessive fear or stress that is difficult to control and negatively impacts daily functioning.
#
# **Patterns or Anomalies:** Hospitalization discharge rates for those with anxiety disorders are medium to high around the upper half of Lake County.

# %% [markdown]
# ## Dataset #4

# %%
# Graph for dataset #4

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

new_df4.plot(
    column="heartd",
    cmap= 'Blues',
    ax=ax,
    cax=divider.append_axes("bottom", size="5%", pad=0.1),
    legend_kwds={"label": "Heart Disease Mortality Rates", "orientation": "horizontal"},
    legend=True,
);

# %% [markdown]
# **Description of Dataset:** This dataset contains information on mortality rates across Lake County, Illinois. The graph above specifically shows mortality rates for those with heart disease by zip code. Heart disease related deaths refers to individuals who have died of heart disease as the underlying cause.
#
# **Patterns or Anomalies:** The mortality rate for those with heart disease are generally medium across Lake County.

# %% [markdown]
# ## Dataset #5

# %%
# Graph for dataset #5

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

new_df5.plot(
    column="chlamydia",
    cmap= 'Purples',
    ax=ax,
    cax=divider.append_axes("bottom", size="5%", pad=0.1),
    legend_kwds={"label": "Chlamydia Rates", "orientation": "horizontal"},
    legend=True,
);

# %% [markdown]
# **Description of Dataset:** This dataset contains information on STI rates across Lake County, Illinois. The graph above specifically shows Chlamydia rates by zip code. Chlamydia is a common STI caused by the bacteria Chlamydia trachomatis.
#
# **Patterns or Anomalies:** Chlamyida rates are the highest around the upper right side of Lake County.
